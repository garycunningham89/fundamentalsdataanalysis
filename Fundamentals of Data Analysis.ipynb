# %% [markdown]
# # Fundamentals of Data Analysis Assignment Notebook
# ## Submission Date - 12/12/2019
# ### Lecturer - Ian McLoughlin
# ##### Assignment Aim: Using the Python and Seaborn package in a Jupyter notebook stored on a Github repository, the aim is to analyze Michael Waskom's well-known tips dataset using various data analyses.
#
# ### Structure:
# ##### 1. Introduction
#
# ##### 2. The Tips Data-set and Descriptive Statistics.
#
# ##### 3. The Tips Data-set and Regression.
#
# ##### 4. An Analysis of Tip Data-set
#
# ##### 5. Conclusion
#
# ##### 6. Reference List
#
# Instructions
#
# This assessment concerns the well-known tips dataset and the Python packages Seaborn and Jupyter.
#
# The project is worth 100% of your marks for this module, but it is broken into three parts, as follows.
#
# (30%) Description: Create a git repository and make it available online for the lecturer to clone. The repository should contain all your work for this assessment. Within the repository, create a jupyter notebook that uses descriptive statistics and plots to describe the tips dataset. This part is worth 30% of your overall mark.
#
# (30%) Regression: To the above jupyter notebook add a section that discusses and analyses whether there is a r relationship between the total bill and tip amount, and this part is also worth 30%.
#
# (40%) Analyze: Again using the same notebook, analyze the relationship between the variables within the dataset. You are free to interpret this as you wish — for example, you may analyze all pairs of variables, or select a subset and analyze those. This part is worth 40%.

# %% [markdown]
# ## 1. Introduction
#
#
# The tips dataset, popularized by Michael Waskom, the creator of the seaborn package in Python, intends to be used throughout this assignment. Seaborn is a higher level data visualization package than matlplotlib which is built on top of it and Waskom has described it as "If Matplotlib “tries to make easy things easy and hard things possible”, seaborn tries to make a well-defined set of hard things easy too.” (Singh, 2019). The tips dataset contains recorded information surrounding tips received by a waiter in a restaurant over a set period while working in one restaurant.
#
# The data set characteristics he collected are summarized in the following list:
#
# Number of Inputs: 244 - 244 of each attribute.
# Number of Attributes/columns: 7 - Data Gathered in the Restaurant - total_bill, tip, sex, smoker, day, time, size.
# Attribute Measurement:
# * count, total_bill, tip = numeric amounts.
# * sex = Male/Female.
# * smoker = Yes/No.
# * day = Thur, Fri, Sat, Sun
# * time = Lunch/Dinner.
# * size = count of customers per table.
# * analysis Type: Multivariate
#
# The multivariate analysis type utilized by the waiter and thus, Waskom in the Tips Dataset allows a range of measurement techniques on this data set as there is more than one variable and those variables are correlated (Olkin and Sampson, 2001). The intention of this project is to firstly, import the data set, compile various calculations (Python language within and through the Seaborn package) of various variables within the data set in a Jupyter Notebook stored in a GitHub repository and summarize the results with the aid of descriptive statistics, tables and diagrams, where required, to attempt to explain its usefulness and its ties to machine learning, in explaining regression and for data analysis overall.
#
#
# The primary resources for data analysis of the Tips dataset in this assignment are utilizing python programming language through Anaconda, Visual Studio Code, Python.org tutorials and w3schools tutorials with packages such as pandas, seaborn, matplotlib and numpy utilized alongside various other compositions regarding the same. Data visualization is a more efficient way of portraying the findings, results or key observations from a dataset. Matplotlib allows for 2D visualizations but to portray a higher level interface for producing statistical graphics we can use a python package called Seaborn (Willems, 2017) and this will be used throughout in attempt to explain the tips dataset. This assignment is first going to be introduced using descriptive statistic calculations to introduce some of the base calculations to explain the tips dataset. Then a simpler approach for explaining any dataset will be introduced and this can be done using data visualization, i.e. converting data into graphs, maps, charts, and complex dashboards, and this easier for the end user to comprehend, especially in describing larger data sets (Hackernoon, 2018). The primary graphical types that will be used bar charts, line charts, box plots, scatter plots, violin plots and histograms.
#
# The first stage is to import the packages contained or mentioned throughout this assignment. Matplotlib and Pandas are merely used as comparisons and for supplementing the primary package Seaborn. They are imported using the following code structure;

# %%
#Importing the dependencies within the seaborn package
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#allow inline interactive matplotlib plots
# %matplotlib inline
#setting style of graphs in seaborn
sns.set(style="whitegrid")

# %% [markdown]
# Next, to import the dataset we can use either pandas read_csv file and import from the URL as shown below:
#
# ##### >>> tipscsv = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
# ##### >>> tipscsv
#
# However the tips dataset is preloaded on the Seaborn package, for ease of use, and to import the dataset through seaborn we use:

# %%
#defining and loading the tips dataset
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# As seen this returns all columns completed with counts totaling 244 rows x 7 columns and this is too vast a data set to study from this view. We can summarize the datasets first or last 5 rows using the following codes;

# %%
#describing the headed 5 rows of the tips dataset
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#describing the tailed 5 tows of the tips dataset
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# To get a description of the DataFrame which include the column amounts and a breakdown of amounts and data types (dtypes) we can use the Pandas info() function as follows:

# %%
# to desribe the datatypes and the amounts within the tips dataset we use
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %% [markdown]
# The next section concerns attempting to explain the tips dataset further by using descriptive statistics, then attempt to correlate it with regression and finally analyze the tips dataset overall using Seaborn.

# %% [markdown]
# ## 2. The Tips Data-set and Descriptive Statistics.
#
# Descriptive statistics are small outputs which can summarize the data set and can represent the the data points in entirety or a sample of such. Either measures of central tendency, i.e averages of the dataset(mean, median), and measures of variability, i.e. dispersions of the dataset . Variability help describe the range, quartiles, absolute deviation, and variance.
#
# There are two types of data: categorical and numerical data. Categorical data is non numerical data such as gender, race, religion, etc. while numerical data is any data that have a measurement or count in data type, e.g. height, weight, age, etc. Within the tips data set the attributes (verified by info() above) can be subdivided into:
#
# ##### Categorical data:
# * sex
# * smoker
# * day
# * time
#
# ##### Numerical data:
# * total_bill
# * tip
# * size
#
# The first useful descriptive statistic is the Measure of Center or the averages of the dataset. This comes in the form of calculating the median and mean of the dataset. To calculate this Pandas has built in functions which we can use to describe the mean of the total_bill, tip and size attributes and the median of the total_bill and tip columns, as seen below;

# %%
#To find the mean of the total_bill column we use:
average = tips['total_bill'].mean()
print("The average total bill amount in Tips Dataset is:",average)
# Out:
# The average total bill amount in Tips Dataset is: 19.785942622950824

# %%
#To find the mean of the tip column we use:
tipaverage = tips['tip'].mean()
print("The average tip amount in Tips Dataset is:",tipaverage)
# Out:
# The average tip amount in Tips Dataset is: 2.9982786885245902

# %%
#To find the mean of the size column we use:
sizeaverage = tips['size'].mean()
print("The average size in Tips Dataset is:",sizeaverage)
# Out:
# The average size in Tips Dataset is: 2.569672131147541

# %%
#To find the median of the total_bill column we use:
median = tips['total_bill'].median()
print("The median of the total bill amount in Tips Dataset is:", median)
# Out:
# The median of the total bill amount in Tips Dataset is: 17.795

# %%
#To find the median of the tip comlumn we use:
tipmedian = tips['tip'].median()
print("The median of the tip amount in Tips Dataset is:", tipmedian)
# Out:
# The median of the tip amount in Tips Dataset is: 2.9

# %% [markdown]
# As you can see the mean in the total bill, tip and size are displayed where the average bill amount approximately equates to 19.79, this can generate on average an approximate $3 dollar tip and the average table size is somewhere between 2 and 3 customers. This allows a drill down on the data and gives a higher level view on the 244 data points in total. The mean can be verified by utilizing the preloaded mean() function also;

# %%
#finding mean of all numerical data types in the tips dataset using mean()
tips.mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %% [markdown]
# The next type of descriptive statistics which allow understand datasets such as the Tips dataset on another level is the use of the Measure of Variation as variation is inevitable in a dataset (Teo, 2019). The measuring of variation is compiled by calculating the Standard Deviation of the dataset which details the variation in the spread of the values recorded, where a low standard deviation shows values close to the mean and high means spread of values are further from the mean. The mathematical calculation of the standard deviation is simplified by pandas through their sd() function and it is used in Python in the following code:

# %%
# Calculating the standard deviation of the total_bill and tips in the tips dataset.

Totalbillstdev = tips['total_bill'].std()
Tipstdev = tips['tip'].std()
print("The standard deviation from the mean of the Total Bill amount is ", Totalbillstdev)
print("The standard deviation from the mean of the Tip amount is ", Tipstdev)
# Out:
# The standard deviation from the mean of the Total Bill amount is  8.902411954856856
# The standard deviation from the mean of the Tip amount is  1.3836381890011826

# %% [markdown]
# The previous calculations intended to give an oversight of the ability to manipulate datasets for understanding using some python programming but python through pandas has a built in function which return these figures on a simple tabled output as shown below. The describe() function returns all numerical category types and returns the relevant figures for the count, mean, standard deviation, minimum values, lower, median and upper quartile figures (25%, 50%, 75% in table respectively) and finally the max values in the dataset for each of the attributes total_bill, tip and size:

# %%
#using the in built describe function to detail the above statistics in one table
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# These allow a greater understanding of the ranges of the figures but in some datasets they can give a consistent picture of the dataset and for this the use of data visualization techniques in the form of various plots and graphs can allow greater understanding. For example the below histograms show the graphing of the three numerical outputs above;

# %%
#creating a histogram of the size, tip and total_bill columns in the tips dataset
tips.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021374C19B38>,
# ...
#       dtype=object)

# %% [markdown]
# This depicts each attribute in a more reader friendly version and it shows the following figures in a graphical format which is much more detailed and comprehensible;
#
# * Size =
#
# X axis = 1-6 Persons at the table, Y Axis = 0 - 160 of customers table size.
#
# * Tip =
#
# X axis = 1-10 Tip amount given, Y Axis = 0 - 80 of customers tip amounts.
#
# * Total_Bill =
#
# X Axis = 3.070- 50.81 Total Bill amounts received, Y Axis = 0 - 70 of customers bill amounts.
#
# To display the percentiles, Seaborn has a plot type known as a box plot which can depict ranges in a more comprehensible and visual depiction for the understanding of the dataset. The range in each attribute total_bill, tip, and size are showing with a blue box depicting the most common amounts with the mean in a vertical line in the middle. Stemming from the box the range expands with two lines to the next outermost range and the remainder are depicted with dots on the lesser common percentile ranges.

# %%
# Graphical depiction of quartile ranges in the form of a boxplot.
boxpl = sns.boxplot('total_bill', data=tips)
boxpl.set_title("Boxplot showing the Total Bill amounts in the Tips Dataset.")
# Out:
# Text(0.5, 1.0, 'Boxplot showing the Total Bill amounts in the Tips Dataset.')

# %%
# Graphical depiction of quartile ranges in the form of a boxplot.
tipboxpl = sns.boxplot('tip', data=tips)
tipboxpl.set_title("Boxplot showing the Tip amounts in the Tips Dataset.")
# Out:
# Text(0.5, 1.0, 'Boxplot showing the Tip amounts in the Tips Dataset.')

# %%
# Graphical depiction of quartile ranges in the form of a boxplot.
sizeboxpl = sns.boxplot('size', data=tips)
sizeboxpl.set_title("Boxplot showing the size amounts in the Tips Dataset.")
# Out:
# Text(0.5, 1.0, 'Boxplot showing the size amounts in the Tips Dataset.')

# %% [markdown]
# As seen these graphs mirror the tip. size and total_bill as explained previously.
#
# We can also use graphics to depict the categorical data contained within the tips dataset. The following pie chart and bar chart plotted using matplotlib and seaborn depict each categorical data type, sex, smoker, day time with legends depicting the color coding and the percentages including in the former 3 types with the day not including a percentile depiction.
#
# The pie chart show that the tips dataset is split into 64.3% Male customers and 35.7% customers where the bar chart depicts the total respondents in numerical amounts which are included in the first few lines of the graph;

# %%
#using pie chart and bar chart to describe the sex column in the tips dataset
type_counts = tips['sex'].value_counts()
tips2 = pd.DataFrame({'sex': type_counts}, 
                     index = ['Male', 'Female']
                   )
tips2.plot.pie(y='sex', figsize=(10,10), autopct='%1.1f%%')
sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
bar1 = sns.countplot(x='sex', data=tips)
print(tips2, bar1)
# Out:
#         sex
# Male    157
# Female   87 AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# The second pie chart shows a graphical depiction of the customers who smoked and those who did not, split into "Yes" and "No" columns returning Yes in blue with 38.1% and No in orange with 61.9%, i.e. 93 vs 151, and the bar chart shows the same;

# %%
#using pie chart and bar chart to describe the smoker column in the tips dataset
type_counts = tips['smoker'].value_counts()
tips3 = pd.DataFrame({'smoker': type_counts}, 
                     index = ['Yes', 'No']
                   )
tips3.plot.pie(y='smoker', figsize=(10,10), autopct='%1.1f%%')
sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
bar2 = sns.countplot(x='smoker', data=tips)
print(tips3, bar2)
# Out:
#      smoker
# Yes      93
# No      151 AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Similarly, the third set of graphs splits the customers Lunch and Dinner with 27.9% (68 customers) and 72.1% (176 customers) respectively;

# %%
#using pie chart and bar chart to describe the time column in the tips dataset
type_counts = tips['time'].value_counts()
tips4 = pd.DataFrame({'time': type_counts}, 
                     index = ['Lunch', 'Dinner']
                   )
tips4.plot.pie(y='time', figsize=(10,10), autopct='%1.1f%%')
sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
bar3 = sns.countplot(x='time', data=tips)
print(tips4, bar3)
# Out:
#         time
# Lunch     68
# Dinner   176 AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# The last pie chart is slightly different from the previous three in that there is not percentile split so as to show how a graph can split more than two variables as seen in the day column within the dataset. As seen the least customers recorded were on Friday and the most on Saturday which accounts for almost half the respondents. The remainder is split between Thursday and Sunday where Sunday has slightly more respondents than Thursday. The graph thereafter shows the respective totals of customers i.e. 62, 19, 87, 76, in bar chart form;

# %%
#using pie chart and bar chart to describe the day column in the tips dataset
type_counts = tips['day'].value_counts()
tips5 = pd.DataFrame({'day': type_counts}, 
                     index = ['Thur', 'Fri', 'Sat', 'Sun']
                   )
tips5.plot.pie(y='day', figsize=(10,10))
sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
ax = sns.countplot(x='day', data=tips)
print(tips5, ax)
# Out:
#       day
# Thur   62
# Fri    19
# Sat    87
# Sun    76 AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # 3. The Tips Data-set and Regression.
#
# Classification and prediction are forms of data analysis which can be used to extract models describing important data classes or to predict future data trends (Han, 2006) and after introducing the classification of the tips dataset above we can now move towards introducing and explaining a major type of prediction known as regression. Regression is a powerful analytical tool which allows examining relationship between two or more variables within a dataset (Foley, 2018). By mathematical definition, regression is the process of deducing the function which produces an unknown value by using some of the known values to approximate the function, i.e. "fit a mathematical function describing a curve, so that the curve passes as close as possible to all the data points" (Marsland, 2015, p. 7). Within the regression analysis of the tips dataset the intention is to analyze whether there is a correlation or link between the tip and total_bill columns recorded. The dependence and independence of the "tip" and the "total_bill" variables with each other interchangeably will be analyzed while using seaborn data visualization techniques in the attempts to do so. The dependent variable in this analysis will be the tip and the analysis intends to portray whether the independent variable, i.e. the total bill amount, that the respondents were charged impacted the tip amount. In this sense we tend to use regression analysis to answer whether the tip amount is dependent by the total bill amount.
#
# Firstly the following graphs plots these variables against each other using scatterplots and lineplots to display the variables in a visual representation;

# %%
#using relplot and scatter type to plot the variables tip and total_bill column against each other
sns.relplot(x="tip", y="total_bill", data=tips, kind = "scatter", color='r')

# %%
#using relplot and line type to plot the variables in the tip and total_bill column against each other
sns.relplot(x="tip", y="total_bill", data=tips, kind = "line", color='g')

# %% [markdown]
# The graphs show that although there are noise or variances within the tip and total bill columns overall, it does seem on a high level view that there is some linear overlap between them and within these graphical assumptions a regression analysis is to be undertaken in the form of a linear regression analysis. A common statistical action is to use linear regression to separate classification problems where the line acts as a divide between the different classes (Marsland, 2015). This can be done by finding the indicator variable by manipulating the data to solve the regression problem or to complete a repeated regression, once for each classification.
#
# Within the seaborn dataset there are some functions which instinctively reproduce regressional analysis which require at least three mandatory parameters >>> (x, y, dataset). The Seaborn lmplot() and regplot() functions are the primary examples and they are called with regards the tip and total bill columns as follows:

# %%
#using Seaborns regplot to show tip and total bill columns linear regression in tips dataset
sns.regplot(x="tip", y="total_bill", data=tips, color = "r")

# %%
#using Seaborns lmplot to show tip and total bill columns linear regression in tips dataset
sns.lmplot(x="tip", y="total_bill", data=tips)

# %% [markdown]
# To view these the linear nature of the overlap columns with similar data points either side of the lines tends to show that the increase in the tip amount on the x axis is related to the increase in the total bill amount on the y axis. For example if you look at the mean figure of $2.99 for tip amount on the x axis and the $19.78 of total bill amount on the y axis, the majority of the datapoints converge within this range and increase or decrease, for the most part, as the amounts increase. For example, the datapoint at the farthest right of the regression line, almost directly above the $10.00 on the x axis and in line with the $50.00 on the y axis depicts this relative increase. On the other hand those which may not be within the immediate surroundings of the line are known as outliers, or exceptions (Medium, 2018).
#
# Furthermore, as linear regression analysis hopes to predict trends the shaded areas either side of the lines are to portray the statistical mean along the line with a view of predicting generally the tip value at each point. This phenomenon known as the confidence interval reinforces the feeling that those on the extremes from the line and the shaded area are merely exceptions rather than the norm. There are further regressional analyses which can account for the spread of the dataset and the confidence interval. The following example deters the line off straight and it can be called using the parameter lowess as True, as below.

# %%
#using Seaborns lmplot including the lowess parameter in showing the tip and total bill columns linear regression analysis.
sns.lmplot(x="tip", y="total_bill", data=tips, lowess=True)

# %% [markdown]
# As shown, the linear variation is not extreme in the tips dataset so as to reinforce the nature of the regression analysis, the linearly nature of the dataset and how the increase in tip is intertwined with the increase in the total bill.
#
# A third variable can be added to the regression analysis using the hue parameter within the lmplot() function. In the following two examples, to add a further element to the regression analysis, an attempt to asses whether the categorical data types sex and smoker within the tips datasets have an effect of the total bill and/or the tip amount will be completed after the graphs:

# %%
#using Seaborns lmplot including the sex variable in showing the tip and total bill columns and linear regression analysis.
sns.lmplot(x="tip", y="total_bill", hue = "sex", data = tips)

# %% [markdown]
# The graph depicts Male customers in blue and Female in orange and the graph does not depict a huge gender difference in influencing the tip amount as influenced by the total bill. To look at the Male respondents they similarly reflect the linear analysis as their tip amount more accurately matches their bill amount and their confidence interval is narrow to reflect little variance from the statistical means. Females on the other hand have a narrower tip amount regardless of the bill amount with more inputs falling in the range $2 - $4. With some tips falling below this and very no tips exceeding $7 dollars their confidence interval is much vaster in span.

# %%
#using Seaborns lmplot including the smoker variable in showing the tip and total bill columns and linear regression analysis.
sns.lmplot(x="tip", y="total_bill", hue = "smoker", data = tips)

# %% [markdown]
# With regards the smoker variable in line with tip amount and bill amount, the smokers, in blue have a greater confidence interval, are more vague in their tip amounts and have more outliers than the non smokers. The tips a smoker could be said to be less influenced by the bill amount and could be harder to predict.
#
# In the next section an analysis of other elements of the tips dataset will be introduced alongside using different data visualizations will be introduced so to as to assess the tips dataset further.

# %% [markdown]
# # 4. An Analysis of Tip Data-set
#
# In composing an analysis of some of the facets of the tips dataset, the Seaborn package has some very effective graphical tools and the use of these data visualization tools intends to portray the relationship between some the various subsets within. For analyzing subsets within data sets, we can use Seaborn packages to show the relationship between x and y and can be defined further using the hue, size and style parameters. A third variable can be included by using all 3 of these parameters which you will see hereafter, but they can be more difficult to interpret and more ineffective. Some of the Seaborn tools or functions that will be used will be are as follows;
#
# ##### * Pairplot
# ##### * Scatterplot
# ##### * Relplot
# ##### * Lineplot
# ##### * Catplot
# ##### * Stripplot
# ##### * Swarmplot
# ##### * Boxenplot
# ##### * Pointplot
# ##### * Boxplot
# ##### * Violinplot
#
#
#
# The numerical data types within the tips dataset of customer count, total_bill and tip have been analyzed in the above section on regression using regplot() and lmplot(), which are both default examples of scatterplots. A scatterplot is the one the best way of graphical analyzing the relationship between variables (Singh, 2019).
#
# The four types of analysis which will be undertaken, with the aid of the above Seaborn functions, are as follows:
#
# * Univariate Analysis
# * Bivariate Analysis
# * Multivariate or 3rd Variable Analysis
# * Multivariate or 4th Variable Analysis
#
# ## Univariate Analysis
#
# To complete the base graphical analysis of the numerical data types we use the pairplot() function which produces a specific histogram, scatterplot and catplot graph for each variable as shown, as an example of a univariate diagram;
#
# ### Pairplot

# %%
#pairplot showing 3 different graphs for each size, total_bill and tip in the tips dataset
sns.pairplot(tips)

# %% [markdown]
# ## Bivariate Analysis
#
# The relplot (relational plot) can output scatterplots as default or lineplot and catplot (categorical plot) can output the stripplot (as default), the boxplot, violinplot, and other plots used within this dataset (and more within the ReadME, from Seaborn documentation, 2019). The adapt from their defaults using the [kind = " "] parameter as shown in the below output. The following relational line plot is similar to the regression analysis above with the hue = "sex" alongside the tip and total_bill on the x and y axis respectively. As mentioned the more the variables, the more difficult it is to compare them but the graph tends to show that the Female variable shows a narrower line with lesser tip amounts versus the total bill than that of the Male, confirming the regression findings above.
#
# ### Relplot((kind = 'line'))/Lineplot()

# %%
#plotting line graph through relplot() showing tip and total bill amounts with 3rd variable sex included
sns.relplot(x="tip", y="total_bill", hue="sex", kind = "line", data=tips);

# %% [markdown]
# Next we can use the categorical data graphs to analyze the four categorical data types within the tips data set and their separate relationships with first, the total bill amount and then, the tip amount. The catplot() default is a stripplot() and we will use the default to display the total bill amount and another plot type called swarmplot() to indicate the relationship with each categorical data type and the tip amount in a series of bivariate analyses. After each data visualization a brief analysis will be added.
#
# ### Catplot((kind = 'strip'))/Stripplot()

# %%
#categorical plot (catplot()) showing the relationship between the total bill and sex variables 
sns.catplot(x="sex", y="total_bill", data=tips)

# %% [markdown]
# ###### Total Bill Amount vs Sex Variable: Males have more respondents and tend to have higher total bill amounts than Female

# %%
#categorical plot (catplot()) showing the relationship between the total bill and smoker variables 
sns.catplot(x="smoker", y="total_bill", data=tips)

# %% [markdown]
# ###### Total Bill Amount vs Smoker Variable: There are less smokers overall but those that do smoke tend to have a greater spread of total bill amounts.

# %%
#categorical plot (catplot()) showing the relationship between the total bill and time variables 
sns.catplot(x="time", y="total_bill", data=tips)

# %% [markdown]
# ##### Total Bill Amount vs Time Variable: Dinner time provides more and higher bill amounts than lunch time.

# %%
#categorical plot (catplot()) showing the relationship between the total bill and day variables 
sns.catplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# ###### Total Bill Amount vs Day Variable: Thursday and Friday are quieter than Saturday and Sunday, with Friday significantly so. Saturday seems to be the restaurants busiest time but the spread of bill amounts between it and Sunday are similar.

# %% [markdown]
# ### Catplot((kind = 'swarm'))/Swarmplot()

# %%
#swarmplot() showing the relationship between the tip amount and sex variables in the tips dataset 
sns.swarmplot(x="sex", y="tip", data=tips)

# %% [markdown]
# ###### Tip Amount vs Sex Variable: The Male respondents have a wider distribution of tips as well in line with more respondents. Both Male and Female respondents are within the range of the mean with Male respondents more likely to have higher than the mean tip amount than the Females.

# %%
#swarmplot() showing the relationship between the tip amount and smoker variables in the tips dataset
sns.swarmplot(x="smoker", y="tip", data=tips)

# %% [markdown]
# ###### Tip Amount vs Smoker Variable: The non smokers have a greater tendency towards the mean tip amount although both distribution shapes are somewhat similar in line with their relative respondents.

# %%
#swarmplot() showing the relationship between the tip amount and time variables in the tips dataset
sns.swarmplot(x="time", y="tip", data=tips)

# %% [markdown]
# ###### Tip Amount vs Time Variable: Lunch time is, as seen, quieter than dinner time and also has a narrower distribution in tip amounts with more tending to tip below the mean per respondent at Lunch time.

# %%
#swarmplot() showing the relationship between the tip amount and day variables in the tips dataset
sns.swarmplot(x="day", y="tip", data=tips)

# %% [markdown]
# ###### Tip Amount vs Day Variable: Thursday and Sunday have similar distributions. Friday is sparse in respondents to accurately assess but it quiet a wide distribution with respondents on Saturday the most unpredictable with some below and significantly above the mean.

# %% [markdown]
# ## Multivariate (3rd Variable) Analysis
#
# A third variable can be added into the Seaborn plot using [hue = " "] which can add to the analysis of a dataset. Scatterplots and lineplots can be difficult to interpret with 3 variable but we can use other categorical graphs such as boxenplot() and pointplot(), as seen below, to assess multivariate analysis.
#
# ### Catplot((kind = 'boxen'))/boxenplot()

# %%
#boxenplot() showing the relationship between the total bill amount, smoker and sex variables in the tips dataset
sns.boxenplot(x="sex", y="total_bill", hue = "smoker", data=tips)

# %% [markdown]
# The distribution shows the mean distributions in horizontal lines across the box and the deviation from the mean in boxes stemming from this central mean interval box. From this we can deduce:
#
# * Males in this dataset were more likely to be smokers than Females.
# * Male smokers paid above the mean bill amount and have a wider deviation from the mean.
# * Female smokers have a narrower deviation from the mean and are closer to the mean of 19.78.
# * Female non smokers are close to the mean, have the narrowest spread overall but tend to be above rather than below.
# * Male non smokers are below the total bill mean, the widest spread overall and more likely to spend below the mean.
#
# ### Catplot((kind = 'point'))/pointplot()

# %%
#pointplot() showing the relationship between the total bill amount, day and sex variables in the tips dataset
sns.catplot(x="day", y="total_bill", hue = "sex", kind = 'point', data=tips)

# %% [markdown]
# The horizontal lines joined by points depict the lower end and higher end of the deviation from the mean with female in orange and the males in blue. The vertical lines are the daily trends from Thursday - Sunday. From this we can figure:
#
# * Thursday was the day with the least total bill amounts from both Male and Female. Male respondents had the highest bill amount of Thursday but their lowest mean of the four days.
# * Friday was the widest range of low to high bill amounts with Females mean decreasing from the previous day and the Males increasing. Males had the highest bill amount and female the lowest bill amount of the whole dataset on Friday.
# * Saturdays means between Males and Female are the closest in the dataset with a great increase in the female bill amounts and also steady incline in the males.
# * Sundays shows a leveling on the incline for the total bill amount for Females but it shows the continuous gradual incline day on day from Thursday for the Male respondents.
#
# ## Multivariate (4th Variable) Analysis
#
# It is possible to add a fourth variable on certain catplot() distribution plots using [hue = " "] and [col = " "] and Seaborn allows for graphical display of the fourth variable by splitting the plots into separate columns based on the input after [col = " "]. The last data representations will contain boxplot() and violinplot() categorical distribution plots with a brief description of the visualization in under the plots below. Data visualization with four variables on the one graphical output is possible in the form of 3 dimensional graphs, heat maps and so on but they can be more difficult to decipher for the reader and less explanatory or comprehensible as a result.
#
# ### Catplot((kind = 'box'))/boxplot()

# %%
#boxplot() showing the relationship between the total bill amount, time, smoker and sex variables in the tips dataset
sns.catplot(x="time", y="total_bill", hue="smoker", col="sex", data=tips, kind="box")

# %% [markdown]
# The boxplot above has split the graph based on sex with left showing male and the right showing female.
# The x axis contains time column, further split into two graphs, left for lunch time and right for dinner time.
# The coloring of the graphical outputs is further split, as the legend shows, by the smoker category, i.e. into yes and no, with yes in blue on the left and no in orange on the right.
# The y axis depicts the total_bill and is mapped onto the time column on the x axis using box plot graphs which show the distribution using boxes with horizontal lines, depicting the mean of the distribution, and two lines with plotted dots there after showing the entire distribution from bottom to top of the depiction.
#
# From the boxplot we can deduce many things and here are five observations;
# * Males smokers tend to spend more than non smokers and in males overall at dinner and have the widest total_bill range, farthest from the mean, at dinner time, and the opposite can be said overall within the male graph for lunch time.
# * Female smokers tend to show the same tendencies but they are more predictable with their total_bill and closer to the mean total bill overall and similarly the opposite is viewable at lunch time.
# * Male non smokers have a fairly constant distribution of total bill column in both graphs, regardless of the time, with few exceptions with their bill being similar to each other in deviation and distribution from the mean.
# * Female non smokers vary in the distribution from the mean with dinner time similarly more busy in terms of amount of respondents and higher bill amounts.
# * Overall the best bill amount came from and tend to come from male smokers at dinner time. The least total_bill came from female smokers at dinner time but you tend to get lesser bill amounts from female non smokers at lunchtime.

# %% [markdown]
# ### Catplot((kind = 'violin'))/violinplot()

# %%
#violinplot() showing the relationship between the total bill amount, smoker, day and sex variables in the tips dataset
sns.catplot(x="day", y="total_bill", hue="smoker", col="sex",data=tips, kind="violin", split=True);

# %% [markdown]
# The last plot, a violin plot also has split the graph based on sex with left showing male and the right showing female.
# The x axis contains day column, further split into 4 graphical outputs, left to right - Thur, Fri, Sat and Sun.
# The coloring of the graphical outputs is further split, as the legend shows, by the smoker category, i.e. into yes and no, with yes in blue on the left and no in orange on the right of the violin plot.
# The y axis depicts the total_bill and is mapped onto the day column on the x axis using violin plot graphs which show the distribution using oblong, elliptical shapes with vertical line spits and darker mid range for depicting the mean of the distribution. The violin shape stems from convergence points spread far from the mean and the colored curves concave to meet these end points.
#
# From the violin plot we can deduce many things and here are five observations;
# * Males smokers tend to spend more than non smokers and in males overall. There is more of an even distribution (look at the blue curves shape vs the orange) every day except Friday, and have the widest total_bill range, highest from the mean, on Saturday.
# * Female smokers are actually more sporadic in total bill amounts. The have a wider range of high total bill amounts overall than non smokers but this is changeable day on day where Thursday and Saturday the bill amounts a higher range but Friday and Sunday the female smokers were closer to the total bill mean.
# * Male non smokers, as per the graph are the most predictable in their distribution day on day with the violin plot showing the most similar concave shaping, meaning they tend to trend for the mean bill amount regardless of the day with fairly even predictable distribution from it, never highest, never lowest.
# * Female non smokers, on the other hand, vary in the distribution from the mean with all four violin plots with different shaping and placement on the graph with regards distribution. Overall their respondents are more likely to be near the mean than the smokers but their deviation from it was less on Thursday and approximately very close to it all other days with Sunday the only day that the range of bill amounts surpassed that of the female smokers significantly.
# * Overall the best bill amount similar to the boxplot above, comes from Males smokers, on Saturday. Conversely, Female smokers produce the lowest likelihood of total bill amount on Saturday. Non smokers, both male and female, show the trend to be more consistent in the distribution from the mean than all smoker respondents.

# %% [markdown]
# # 5. Conclusion
#
# The main aim of this assignment was to show some possible ways to summarize our dataset in a meaningful way by using the Seaborn package. Seaborn is one of the primary python packages used in statistical analysis or data science projects as a major advantage is that they compute complicated calculations and graph plotting into few lines of Python scripts as viewed throughout this assignment and data analysis, as such, becomes much easier and time-saving. The seaborn package advances on the Matplotlib package by producing arguably better data visualization, in fewer lines of code. The tips dataset is an effective dataset in data analysis for showing the relationships between variables, prediction and regression analysis. The seaborn package is best suited for the tips dataset analysis as it was compiled by Michael Waskom, the creator of Seaborn, and is a great introductory dataset for performing data analysis.

# %% [markdown]
# # 6. Reference List

# %% [markdown]
# ##### Class Content, Background Reading and Python Learning Tutorials were preliminary references supplemented by the following list of references;
# * Python Software Foundation. Accessed online at: https://www.python.org/
# * GitHub Guides. Mastering markdown. https://guides.github.com/features/mastering-markdown/
# * w3Schools.com Tutorials. Accessed online at: https://www.w3schools.com
# * Python by Programiz Tutorials. Accessed online at: https://www.programiz.com/
# * Pandas: Python Data Analysis Library. Accessed online at: https://pandas.pydata.org.
# * NumPy.org. Accessed online at: http://www.numpy.org.
# * Seaborn (2019) Official Seaborn Tutorial. Accessed online at: https://seaborn.pydata.org/tutorial.html
# * Stack Overflow - Various queries for comparison and improving code output. Accessed online at: https://stackoverflow.com.
# * Git (2019) Git Book. Accessed online at: https://git-scm.com/book/en/v2
# * SciPy.org (2019) Quickstart Tutorial. Accessed online at: https://docs.scipy.org/doc/numpy/user/quickstart.html
# * matplotlib (2019) Pyplot Tutorial. Accessed online at: https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html
# * Jupyter (2019) Project jupyter. Accessed online at: https://jupyter.org/.
# * Waskom, M. (2019) seaborn. Accessed online at: https://seaborn.pydata.org/.
# * Waskom, M. (2019) Tips data set. Accessed online at: https://github.com/mwaskom/seaborn-data/blob/master/tips.csv.
# * Waskom, M. (2019) Github Account. Accessed online at: https://github.com/mwaskom?tab=repositories.
# * Waskom, M. (2019) Bio NYU. Accessed online at: https://www.cns.nyu.edu/~mwaskom/index.html
# * Seaborn (2019) Visualizing statistical relationships. Accessed online at: https://seaborn.pydata.org/tutorial/relational.html
# * Marsland, S. (2015) Machine Learning: An Algorithmic Perspective. Taylor and Francis Group.
# * Investopedia (2019) Descriptive Statistics. Accessed online at: https://www.investopedia.com/terms/d/descriptive_statistics.asp
# * Doshi, S. (2019) Analyze the data through data visualization using Seaborn. Towards Data Science. Accessed online at: https://towardsdatascience.com/.analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e
# * Hackernoon (2018) What Is Data Visualization? Definition, History, and Examples. Accessed online at: https://hackernoon.com/what-is-data-visualization-definition-history-and-examples-e51ded6e444a.
# * Olkin, I. and Sampson, A. R. (2001) Multivariate Analysis: Overview, in International Encyclopedia of the Social & Behavioral Sciences. Accessed online at: https://www.sciencedirect.com/topics/medicine-and-dentistry/multivariate-analysis.
# * Taylor, J. (2011) Stats 202: Data Mining. Stanford Univeristy. Accessed online at: http://statweb.stanford.edu/~jtaylo/courses/stats202/visualization.html.
# * Michalski, R. S., Carbonell, J. G. and Mitchel, T. M. (2014) Machine Learning: An Artificial Intelligence Approach, Volume 1.
# * Han, J. (2006) Data Mining: Concepts and Techniques. Accessed online at: http://rizalespe.lecture.ub.ac.id/files/2015/10/DM-04-1-Klasifikasi.pdf
# * Python Charts (2019) A Short Intro to Seaborn. Accessed online at: https://www.pythoncharts.com/2019/04/15/intro-to-seaborn/
# * Willems, K (2017) Python Seaborn Tutorial For Beginners. Accessed online at: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial.
# * Teo, B. G. (2019) A Quick Guide on Descriptive Statistics using Pandas and Seaborn. Towards Data Science. Accessed online at: https://towardsdatascience.com/a-quick-guide-on-descriptive-statistics-using-pandas-and-seaborn-2aadc7395f32
# * Singh, S. (2019) Become a Data Visualization Whiz with this Comprehensive Guide to Seaborn in Python. Analytics Vidhya. Accessed online at: https://www.analyticsvidhya.com/blog/2019/09/comprehensive-data-visualization-guide-seaborn-python/
# * Wajiha (2019) Python Seaborn Tutorial | Data Visualization Using Seaborn. Accessed online at: https://www.codementor.io/wajihaurooj/python-seaborn-tutorial-data-visualization-using-seaborn-wpj9qydr2.
# * Foley (2018) What is Regression Analysis and Why Should I Use It? Accessed online at: https://www.surveygizmo.com/resources/blog/regression-analysis/.
# * Medium (2018) Data Visualization with Python and Seaborn — Part 4: LM Plot & Reg Plot. Accessed online at: https://medium.com/@neuralnets/data-visualization-with-python-and-seaborn-part-4-9b0119887130
