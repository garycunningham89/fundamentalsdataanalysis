# %% [markdown]
# # Fundamentals of Data Analysis Assignment Notebook
# ## Submission Date - 29/11/2019
# ### Lecturer - Ian McLoughlin
# ##### Assignment Aim: Using the Python and Seaborn package in a Jupyter notebook stored on a Github repository, the aim is to analyse Michael Waskom's well-known tips dataset using various data analyses.

# %% [markdown]
# ### Structure:
# ##### 1. Introduction
#
# ##### 2. The Tips Data-set and Descriptive Statistics.
#
# ##### 3. The Tips Data-set and Regression.
#
# ##### 4. An Analysis of Tip Data-set
#
# ##### 5. Conclusion
#
# ##### 6. Reference List
#
# Instructions
#
# This assessment concerns the well-known tips dataset and the Python packages seaborn and jupyter.
#
# The project is worth 100% of your marks for this module, but it is broken into three parts, as follows.
#
# (30%) Description: Create a git repository and make it available online for the lecturer to clone. The repository should contain all your work for this assessment. Within the repository, create a jupyter notebook that uses descriptive statistics and plots to describe the tips dataset. This part is worth 30% of your overall mark.
#
# (30%) Regression: To the above jupyter notebook add a section that discusses and analyses whether there is a r relationship between the total bill and tip amount, and this part is also worth 30%.
#
# (40%) Analyse: Again using the same notebook, analyse the relationship between the variables within the dataset. You are free to interpret this as you wish — for example, you may analyse all pairs of variables, or select a subset and analyse those. This part is worth 40%.

# %% [markdown]
# ## 1. Introduction
#
# The data set characteristics are summarized in the following list:
#
# No of Inputs: 243 - 243 of each class above.
# Number of Attributes: .6 - Data Gathered in the Restaurant - total_bill, tip, sex, day, time, size.
# Attribute Measurement: total_bill, tip = numeric amounts. Sex = Male/Female. Smoker = Yes/No. Time = Lunch/Dinner. Size = count.
# Analysis Type: Multivariate
#
# The multivariate analysis type utilized by Waskom in the Tips Dataset allows a range of measurement techniques on this data set as there are more than one variable and those variables are correlated (Olkin and Sampson, 2001). The intention of this project is to firstly, import the data set, compile various calculations (Python through Seaborn, Pandas, etc.) of various variables within the data set in a Jupyter Notebook stored in a GitHub repository and summarize the results with the aid of descriptive statistics, tables and diagrams, where required, to attempt to explain its usefulness and its ties to machine learning, in explaining Regression and for data analysis overall.
#
# The primary resources for data analysis of the Tips dataset in this assignment are utilising python programming language through Anaconda, Visual Studio Code, Python.org tutorials and w3schools tutorials with packages such as pandas, seaborn, matplotlib and numpy utilized alongside various other compositions regarding the same.
#
# Descriptions of Dataset;
# tips.data() -shows entire data set.
# tips.head() - shows first 5 rows of the data set.
# tips.tail() - shows last 5 rows of the dataset.
# tips.describe() -gives a statistical summary of the dataset.
# tips.shape() - tells amounts of rows and columns in format: (rows, columns)
# tips.columns() - gives output of the columns headers and the 'dtype'.b
# tips["class"].value_counts() - separates the column class and gives output of each as well as the dtype as int64.

# %% [markdown]
# print(data[].describe())
# data.hist()
# plt.show()
# data.plot(kind='scatter', x = 'tip', y = 'total_bill')
# plt.show()
# data.plot(kind='scatter', x = 'sex', y = 'smoker')
# plt.show()
# data.plot(kind='scatter', x = 'time', 'count')
# plt.show()
# #The following templates for statistic analysis adapted from python.org tutorials were
# #used as a basis for analysis and adapted for use with the Tips Dataset.
# #from statistics import mean, median, mode, stdev
# #avg_value = mean()
# #median_value = median()
# #mode_value = mode()
# #std_dev = stdev()
# #max_value = max()
# #min_value = min()

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## 2. The Tips Data-set and Descriptive Statistics.
#
# Classification - grouping examples into different classes.
#
# Descriptive statistics are small outputs which can summarize the data set and can represent the the datapoints in entirety or a sample of such.
#
# Either measures of central tendency, i.e averages of the dataset(mean, median, mode), and measures of variability, i.e. dispersions of the dataset. Variability help describe the range, quartiles, absolute deviation, and variance.
#
# These can be done use data visualisation, i.e. converting data into graphs, maps, charts, and complex dashboards, and this easier for the end user to comprehend, especially in describing larger data sets (Hackernoon, 2018). Primary types that will be used bar charts, line charts, box plots, scatter plots, violin plots, histograms, and so on.

# %% [markdown]
# # 3. The Tips Data-set and Regression.
#
# Regression is the process of deducing the function which produces an unknown value by using some of the known values to approximate the function, i.e. "fit a mathematical function describing a curve, so that the curve passes as close as possible to all the datapoints" (Marsland, 2015, p. 7).
#
# A common statistical action is to use linear regression to separate classification problems where the line acts as a divide between the different classes (Marsland, 2015). This can be done by finding the indicator variable by utilising the data to solve the regression problem or to complete a repeated regression, once for each classification.

# %% [markdown]
# # 4. An Analysis of Tip Data-set
#
# Seaborn Tutorial:
#
# For analysing subsets within data sets, we can use Seaborn packages to show the relationship between x and y and can be defined further using the hue, size and style parameters.
#
# A third variable can be included by using all 3 of these parameters but it can be difficult to interpret and ineffective.

# %% [markdown]
# seaborn.scatterplot(x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, x_bins=None, y_bins=None, units=None, estimator=None, ci=95, n_boot=1000, alpha='auto', x_jitter=None, y_jitter=None, legend='brief', ax=None, **kwargs)

# %% [markdown]
# seaborn.lineplot(x=None, y=None, hue=None, size=None, style=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, units=None, estimator='mean', ci=95, n_boot=1000, sort=True, err_style='band', err_kws=None, legend='brief', ax=None, **kwargs

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# # 6. Reference List

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Researching stripplots.
tips= sns.load_dataset("tips")
sns.stripplot(x="day", y="total_bill", hue="smoker", data=tips)

# %%
sns.boxplot(x="tip", y="day", data=tips)

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None, color="r")

# %%
sns.catplot(x="sex", y="total_bill", hue="smoker", col="time", data=tips, jitter=True)

# %% [markdown]
# ## The Tips Dataset

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Matplotlib plots
#
# Seaborn plots
#
# Descriptive Statistics
#
# Regression
#
# Analyze

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker",
            data=tips);

# %%
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
tips = sns.load_dataset("tips")
sns.lineplot(x="total_bill", y="tip", data=fmri)

# %%
tips = sns.load_dataset("tips")
sns.lineplot(x="total_bill", y="tip", hue="smoker", data=fmri)

# %%
ax = sns.lineplot(x="tip", y="total_bill", hue="smoker", legend="full", data=tips)

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
sns.swarmplot(x=tips["total_bill"])

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
sns.violinplot(y='day', x='total_bill', data=tips, inner='quartile')
plt.show()

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(tips, height=4).map(plt.scatter, "total_bill", "day").add_legend()
plt.show()

# %%
sns.set_style("whitegrid") #setting the style as whitegrid as seen in tutorials.
sns.FacetGrid(tips, height=4).map(sns.distplot, "total_bill").add_legend()
plt.show()
